# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#dist plot allows to show distribution of univariate set of observations
sns.displot(tips['total_bill'], kde=True, bins=40)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind="hex")

# %%
sns.pairplot(tips, hue="sex", palette="Dark2")

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
import numpy as np

# %%
x = np.random.randn(10)
x
# Out:
# array([ 1.23163516,  0.05865658,  0.84445698,  0.39686949, -1.79007925,
#        -0.23279606,  0.66224118,  1.56807054,  0.29595864,  0.03100351])

# %%
sns.kdeplot(x)
# Out:
# <AxesSubplot:ylabel='Density'>
